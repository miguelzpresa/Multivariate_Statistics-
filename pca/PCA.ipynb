# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import load_iris

# Cargar un conjunto de datos de ejemplo
data = load_iris()
X = data.data

# Escalar los datos (opcional, pero recomendado para PCA)
from sklearn.preprocessing import StandardScaler
X_scaled = StandardScaler().fit_transform(X)

# Aplicar PCA
pca = PCA()
pca.fit(X_scaled)

# Varianza explicada por cada componente
explained_variance = pca.explained_variance_ratio_

# Varianza acumulada
cumulative_variance = np.cumsum(explained_variance)

# Graficar la varianza explicada y la varianza acumulada
plt.figure(figsize=(8, 5))
plt.plot(range(1, len(explained_variance) + 1), cumulative_variance, marker='o', linestyle='--')
plt.title('Varianza Explicada Acumulada por el PCA')
plt.xlabel('Número de Componentes')
plt.ylabel('Varianza Explicada Acumulada')
plt.grid(True)
plt.show()

# Seleccionar el número de componentes según un umbral de varianza explicada acumulada
threshold = 0.95
n_components = np.argmax(cumulative_variance >= threshold) + 1

print(f"Para explicar al menos el {threshold * 100}% de la varianza, se necesitan {n_components} componentes.")
# Out:
# Para explicar al menos el 95.0% de la varianza, se necesitan 2 componentes.

# %%
# Importar las librerías necesarias
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Generar un conjunto de datos de ejemplo
# Si tienes un dataset, puedes cargarlo con pandas
# por ejemplo: df = pd.read_csv('data.csv')
np.random.seed(42)
data = load_iris() # 100 muestras, 5 características

# Estandarizar los datos


# Aplicar PCA
pca = PCA(n_components=2)
pca_components = pca.fit_transform(data_scaled)

# Crear un DataFrame con los componentes principales
df_pca = pd.DataFrame(data=pca_components, columns=['PC1', 'PC2'])

# Visualizar los resultados
plt.figure(figsize=(8, 6))
plt.scatter(df_pca['PC1'], df_pca['PC2'], c='blue', edgecolor='k', s=50)
plt.title('PCA - Primeros dos Componentes Principales')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.grid(True)
plt.show()

# Mostrar la varianza explicada por cada componente principal
explained_variance = pca.explained_variance_ratio_
print('Varianza explicada por cada componente principal:', explained_variance)
# Out:
# Varianza explicada por cada componente principal: [0.29005782 0.23214006]
